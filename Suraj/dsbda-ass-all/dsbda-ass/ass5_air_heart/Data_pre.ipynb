# %%
import pandas as pd

# %%
air = pd.read_csv('airquality.csv')

# %%
air.shape
# Out:
# (153, 7)

# %%
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
air.count()
# Out:
# Unnamed: 0    153
# Ozone         116
# Solar.R       146
# Wind          153
# Temp          153
# Month         153
# Day           153
# dtype: int64

# %%
air.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
air.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind        Temp       Month  \
# count  153.000000  116.000000  146.000000  153.000000  153.000000  153.000000
# mean    77.000000   42.129310  185.931507    9.957516   77.882353    6.993464
# std     44.311398   32.987885   90.058422    3.523001    9.465270    1.416522
# min      1.000000    1.000000    7.000000    1.700000   56.000000    5.000000
# 25%     39.000000   18.000000  115.750000    7.400000   72.000000    6.000000
# 50%     77.000000   31.500000  205.000000    9.700000   79.000000    7.000000
# 75%    115.000000   63.250000  258.750000   11.500000   85.000000    8.000000
# max    153.000000  168.000000  334.000000   20.700000   97.000000    9.000000
#
#               Day
# count  153.000000
# mean    15.803922
# std      8.864520
# min      1.000000
# 25%      8.000000
# 50%     16.000000
# 75%     23.000000
# max     31.000000

# %%
air.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  153 non-null    int64
#  1   Ozone       116 non-null    float64
#  2   Solar.R     146 non-null    float64
#  3   Wind        153 non-null    float64
#  4   Temp        153 non-null    int64
#  5   Month       153 non-null    int64
#  6   Day         153 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 8.5 KB

# %%
A = air.dropna()

# %%
A.shape
# Out:
# (111, 7)

# %%
A = air.fillna(0)

# %%
A.shape
# Out:
# (153, 7)

# %%
A.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    0.0      0.0  14.3    56      5    5

# %%
A = air.fillna(method='pad')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 A = air.fillna(method='pad')
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
A.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    0.0      0.0  14.3    56      5    5

# %%
A = air.fillna(method='backfill')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 A = air.fillna(method='backfill')
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
A.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    0.0      0.0  14.3    56      5    5

# %%
import numpy as np

# %%
A = air['Ozone'].replace(np.nan,air['Ozone'].mean())

# %%
A.head()
# Out:
# 0    41.00000
# 1    36.00000
# 2    12.00000
# 3    18.00000
# 4    42.12931
# Name: Ozone, dtype: float64

# %%
A = air['Ozone'].replace(np.nan,air['Ozone'].mean())

# %%
A.head()
# Out:
# 0    41.00000
# 1    36.00000
# 2    12.00000
# 3    18.00000
# 4    42.12931
# Name: Ozone, dtype: float64

# %%
A = air['Ozone'].replace(np.nan,air['Ozone'].median())

# %%
A.head()
# Out:
# 0    41.0
# 1    36.0
# 2    12.0
# 3    18.0
# 4    31.5
# Name: Ozone, dtype: float64

# %%
A = air['Ozone'].replace(np.nan,air['Ozone'].mode())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 A = air['Ozone'].replace(np.nan,air['Ozone'].mode())
#
# File ~/Documents/College Notes/Sem 6/DSBDA/dsbda-ass/myenv/lib/python3.12/site-packages/pandas/core/generic.py:7835, in NDFrame.replace(self, to_replace, value, inplace, regex)
#    7831             # dest iterable dict-like
#    7832             elif is_dict_like(value):  # NA -> {'A' : 0, 'B' : -1}
#    7833                 # Operate column-wise
#    7834                 if self.ndim == 1:
# -> 7835                     raise ValueError(
#    7836                         "Series.replace cannot use dict-value and non-None to_replace"
#    7837                     )
#    7838                 mapping = {col: (to_replace, val) for col, val in value.items()}
#
# ValueError: Series.replace cannot use dict-value and non-None to_replace

# %%
A.head()
# Out:
# 0    41.0
# 1    36.0
# 2    12.0
# 3    18.0
# 4    31.5
# Name: Ozone, dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
A = imp.fit_transform(air)

# %%
A
# Out:
# array([[  1.,  41., 190., ...,  67.,   5.,   1.],
#        [  2.,  36., 118., ...,  72.,   5.,   2.],
#        [  3.,  12., 149., ...,  74.,   5.,   3.],
#        ...,
#        [151.,  14., 191., ...,  75.,   9.,  28.],
#        [152.,  18., 131., ...,  76.,   9.,  29.],
#        [153.,  20., 223., ...,  68.,   9.,  30.]], shape=(153, 7))

# %%
A = pd.DataFrame(A, columns=air.columns)

# %%
A.head()
# Out:
#    Unnamed: 0     Ozone     Solar.R  Wind  Temp  Month  Day
# 0         1.0  41.00000  190.000000   7.4  67.0    5.0  1.0
# 1         2.0  36.00000  118.000000   8.0  72.0    5.0  2.0
# 2         3.0  12.00000  149.000000  12.6  74.0    5.0  3.0
# 3         4.0  18.00000  313.000000  11.5  62.0    5.0  4.0
# 4         5.0  42.12931  185.931507  14.3  56.0    5.0  5.0

# %%
from sklearn.model_selection import train_test_split

# %%
len(A)
# Out:
# 153

# %%
train, test = train_test_split(A)

# %%
len(train)
# Out:
# 114

# %%
len(test)
# Out:
# 39

# %%
train.head()

# %%
train, test = train_test_split(A, test_size = 0.20)

# %%
len(test)

# %%
len(train)

# %%
A.describe()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
B = scaler.fit_transform(A)

# %%
pd.DataFrame(B).describe()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
B = scaler.fit_transform(A)

# %%
pd.DataFrame(B).describe()

# %%
B = pd.DataFrame(B).describe()

# %%
from sklearn.preprocessing import Binarizer

# %%
bin = Binarizer(threshold=0.5)

# %%
B = bin.fit_transform(B)

# %%
pd.DataFrame(B)

# %%
data=pd.read_csv('student.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
B = le.fit_transform(data['name'])

# %%
B

# %%
B = data[:]

# %%
B['name'] = le.fit_transform(B['name'])

# %%
B

# %%
A

# %%
from sklearn.linear_model import LinearRegression

# %%
X=A['Ozone'].values

# %%
X=X.reshape(-1,1)

# %%
Y = A['Temp']

# %%
model = LinearRegression()

# %%
model.fit(X,Y)

# %%
model.score(X,Y)*100

# %%
model.predict([[128]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
